# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import activations
from tensorflow.keras import Model
from tqdm import tqdm
import os
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from tensorflow.keras import callbacks

classes = {'Normal': 0, 'Adenocarcinoma': 1, 'large_carcinoma': 2, 'squamous_carcinoma': 3}

# On définit les chemins pour accéder aux images
Normal_test=r'test/normal'
Adenocarcinoma_test=r'test/adenocarcinoma'
Large_carcinoma_test=r'test/large.cell.carcinoma'
Squamous_carcinoma_test=r'test/squamous.cell.carcinoma'

Normal_train=r'train/normal'
Adenocarcinoma_train=r'train/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'
Large_carcinoma_train=r'train/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'
Squamous_carcinoma_train=r'train/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'

Normal_valid=r'valid/normal'
Adenocarcinoma_valid=r'valid/adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib'
Large_carcinoma_valid=r'valid/large.cell.carcinoma_left.hilum_T2_N2_M0_IIIa'
Squamous_carcinoma_valid=r'valid/squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa'

# On définit les paramètres de la base de données
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
IMAGE_SIZE=(IMAGE_WIDTH, IMAGE_HEIGHT)
BATCH_SIZE=64
N_CLASSES = 4
EPOCHS = 50

def assign_label(img,class_type):
    return class_type

X = []
y = []

# Fonction permettant d'assigner un label aux images
def make_train_data(class_type,DIR):
    for img in tqdm(os.listdir(DIR)):
        label=assign_label(img,class_type)
        path = os.path.join(DIR,img)
        img = cv2.imread(path,cv2.IMREAD_COLOR)
        img = cv2.resize(img, (IMAGE_WIDTH,IMAGE_HEIGHT))
        
        X.append(np.array(img))
        y.append(str(label))
        
# Assignation des labels aux images
make_train_data(classes.get('Normal'), Normal_test)
make_train_data(classes.get('Normal'), Normal_train)
make_train_data(classes.get('Adenocarcinoma'), Adenocarcinoma_test)
make_train_data(classes.get('Adenocarcinoma'), Adenocarcinoma_train)
make_train_data(classes.get('large_carcinoma'), Large_carcinoma_test)
make_train_data(classes.get('large_carcinoma'), Large_carcinoma_train)
make_train_data(classes.get('squamous_carcinoma'), Squamous_carcinoma_test)
make_train_data(classes.get('squamous_carcinoma'), Squamous_carcinoma_train)

y = np.array(y)
X = np.array(X)

# On sépare la base de données en base d'apprentissage et de test
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X, y, shuffle=True, test_size=0.2, random_state=58954)

X = []
y = []

# Assignation des labels aux images pour la base de données de validation
make_train_data(classes.get('Normal'), Normal_valid)
make_train_data(classes.get('Adenocarcinoma'), Adenocarcinoma_valid)
make_train_data(classes.get('large_carcinoma'), Large_carcinoma_valid)
make_train_data(classes.get('squamous_carcinoma'), Squamous_carcinoma_valid)

y_valid = np.array(y)
X_valid = np.array(X)

k = len(set(y_train))
print("Number of classes, ", k)

# On normalise les données
X_train = X_train.astype('float64')/255
X_test = X_test.astype('float64')/255
X_valid = X_valid.astype('float64')/255

y_train = to_categorical(y_train, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)
y_valid = to_categorical(y_valid, num_classes=4)

labels = '''Normal
Adenocarcinoma
large_carcinoma
squamous_carcinoma
'''.split("\n")

plt.figure(figsize=(16,16))
j = 1
for i in np.random.randint(0,252,16):
    plt.subplot(4,4,j); j+=1
    plt.imshow(X_train[i],cmap = 'Greys')
    plt.axis('off')
    plt.title("Actual: {}".format(labels[np.argmax(y_train[i])]))
# Out:
# 100%|██████████| 54/54 [00:01<00:00, 30.97it/s]
# 100%|██████████| 148/148 [00:02<00:00, 64.83it/s]
# 100%|██████████| 120/120 [00:01<00:00, 93.40it/s]
# 100%|██████████| 195/195 [00:01<00:00, 105.92it/s]
# 100%|██████████| 51/51 [00:00<00:00, 111.06it/s]
# 100%|██████████| 114/114 [00:00<00:00, 114.37it/s]
# 100%|██████████| 90/90 [00:01<00:00, 80.83it/s]
# 100%|██████████| 155/155 [00:01<00:00, 92.80it/s]
# 100%|██████████| 13/13 [00:00<00:00, 32.82it/s]
# 100%|██████████| 23/23 [00:00<00:00, 114.53it/s]
# 100%|██████████| 21/21 [00:00<00:00, 123.63it/s]
# 100%|██████████| 15/15 [00:00<00:00, 122.19it/s]
# Number of classes,  4

# %%
# Création des couches du réseau de neurone
i = layers.Input(shape = (X_train[0].shape))
x = layers.Conv2D(64, (3,3), activation="relu", strides=(2,2), padding="same" )(i)
x = layers.Conv2D(64, (3,3), activation="relu", strides=(2,2), padding="same" )(x)
x = layers.Conv2D(32, (3,3), activation="relu", strides=(2,2), padding="same" )(x)
x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(128, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(k, activation='softmax')(x)

#Construction du modèle:
model = Model(i, x)

model.summary()
#Compilation du modèle :
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.1,patience=3, min_lr=0.00001)

model.fit(X_train, y_train, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data=  (X_valid,y_valid), callbacks=[reduce_lr])
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 3)]     0
#
#  conv2d (Conv2D)             (None, 64, 64, 64)        1792
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        36928
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 32)        18464
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 256)               2097408
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 2,188,004
# Trainable params: 2,188,004
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 12/12 [==============================] - 7s 485ms/step - loss: 1.3188 - accuracy: 0.3482 - val_loss: 1.3904 - val_accuracy: 0.3611 - lr: 0.0010
# Epoch 2/50
# 12/12 [==============================] - 6s 481ms/step - loss: 1.0471 - accuracy: 0.5061 - val_loss: 1.1357 - val_accuracy: 0.4583 - lr: 0.0010
# Epoch 3/50
# 12/12 [==============================] - 5s 452ms/step - loss: 0.8393 - accuracy: 0.6289 - val_loss: 0.8160 - val_accuracy: 0.6667 - lr: 0.0010
# Epoch 4/50
# 12/12 [==============================] - 6s 507ms/step - loss: 0.6383 - accuracy: 0.7260 - val_loss: 0.7943 - val_accuracy: 0.6806 - lr: 0.0010
# Epoch 5/50
# 12/12 [==============================] - 6s 505ms/step - loss: 0.4676 - accuracy: 0.8259 - val_loss: 1.1123 - val_accuracy: 0.5972 - lr: 0.0010
# Epoch 6/50
# 12/12 [==============================] - 6s 466ms/step - loss: 0.3876 - accuracy: 0.8583 - val_loss: 0.7417 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 7/50
# 12/12 [==============================] - 5s 392ms/step - loss: 0.2690 - accuracy: 0.8974 - val_loss: 0.6764 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 8/50
# 12/12 [==============================] - 5s 396ms/step - loss: 0.1994 - accuracy: 0.9190 - val_loss: 0.7820 - val_accuracy: 0.7222 - lr: 0.0010
# Epoch 9/50
# 12/12 [==============================] - 5s 392ms/step - loss: 0.1468 - accuracy: 0.9487 - val_loss: 0.7696 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 10/50
# 12/12 [==============================] - 5s 394ms/step - loss: 0.1016 - accuracy: 0.9690 - val_loss: 0.8267 - val_accuracy: 0.7083 - lr: 0.0010
# Epoch 11/50
# 12/12 [==============================] - 5s 397ms/step - loss: 0.0652 - accuracy: 0.9784 - val_loss: 0.8827 - val_accuracy: 0.7222 - lr: 1.0000e-04
# Epoch 12/50
# 12/12 [==============================] - 6s 458ms/step - loss: 0.0503 - accuracy: 0.9852 - val_loss: 0.9094 - val_accuracy: 0.7361 - lr: 1.0000e-04
# Epoch 13/50
# 12/12 [==============================] - 8s 691ms/step - loss: 0.0485 - accuracy: 0.9892 - val_loss: 0.8995 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 14/50
# 12/12 [==============================] - 8s 701ms/step - loss: 0.0481 - accuracy: 0.9852 - val_loss: 0.9020 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 15/50
# 12/12 [==============================] - 11s 909ms/step - loss: 0.0358 - accuracy: 0.9919 - val_loss: 0.9025 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 16/50
# 12/12 [==============================] - 17s 1s/step - loss: 0.0430 - accuracy: 0.9865 - val_loss: 0.9075 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 17/50
# 12/12 [==============================] - 10s 757ms/step - loss: 0.0367 - accuracy: 0.9892 - val_loss: 0.9131 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 18/50
# 12/12 [==============================] - 8s 628ms/step - loss: 0.0363 - accuracy: 0.9892 - val_loss: 0.9148 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 19/50
# 12/12 [==============================] - 6s 526ms/step - loss: 0.0365 - accuracy: 0.9919 - val_loss: 0.9188 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 20/50
# 12/12 [==============================] - 6s 496ms/step - loss: 0.0383 - accuracy: 0.9892 - val_loss: 0.9204 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 21/50
# 12/12 [==============================] - 6s 469ms/step - loss: 0.0358 - accuracy: 0.9973 - val_loss: 0.9239 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 22/50
# 12/12 [==============================] - 5s 458ms/step - loss: 0.0437 - accuracy: 0.9879 - val_loss: 0.9205 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 23/50
# 12/12 [==============================] - 5s 436ms/step - loss: 0.0409 - accuracy: 0.9919 - val_loss: 0.9183 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 24/50
# 12/12 [==============================] - 6s 459ms/step - loss: 0.0272 - accuracy: 0.9919 - val_loss: 0.9236 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 25/50
# 12/12 [==============================] - 7s 562ms/step - loss: 0.0325 - accuracy: 0.9933 - val_loss: 0.9325 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 26/50
# 12/12 [==============================] - 9s 761ms/step - loss: 0.0313 - accuracy: 0.9973 - val_loss: 0.9382 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 27/50
# 12/12 [==============================] - 8s 702ms/step - loss: 0.0295 - accuracy: 0.9960 - val_loss: 0.9433 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 28/50
# 12/12 [==============================] - 9s 696ms/step - loss: 0.0273 - accuracy: 0.9960 - val_loss: 0.9441 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 29/50
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0388 - accuracy: 0.9879 - val_loss: 0.9418 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 30/50
# 12/12 [==============================] - 11s 929ms/step - loss: 0.0317 - accuracy: 0.9919 - val_loss: 0.9436 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 31/50
# 12/12 [==============================] - 7s 565ms/step - loss: 0.0327 - accuracy: 0.9906 - val_loss: 0.9442 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 32/50
# 12/12 [==============================] - 7s 543ms/step - loss: 0.0289 - accuracy: 0.9919 - val_loss: 0.9482 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 33/50
# 12/12 [==============================] - 6s 494ms/step - loss: 0.0347 - accuracy: 0.9906 - val_loss: 0.9495 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 34/50
# 12/12 [==============================] - 6s 464ms/step - loss: 0.0334 - accuracy: 0.9946 - val_loss: 0.9499 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 35/50
# 12/12 [==============================] - 6s 458ms/step - loss: 0.0298 - accuracy: 0.9919 - val_loss: 0.9543 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 36/50
# 12/12 [==============================] - 5s 434ms/step - loss: 0.0318 - accuracy: 0.9919 - val_loss: 0.9530 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 37/50
# 12/12 [==============================] - 5s 422ms/step - loss: 0.0334 - accuracy: 0.9919 - val_loss: 0.9525 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 38/50
# 12/12 [==============================] - 5s 443ms/step - loss: 0.0343 - accuracy: 0.9946 - val_loss: 0.9492 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 39/50
# 12/12 [==============================] - 5s 416ms/step - loss: 0.0265 - accuracy: 0.9946 - val_loss: 0.9530 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 40/50
# 12/12 [==============================] - 5s 412ms/step - loss: 0.0252 - accuracy: 0.9960 - val_loss: 0.9592 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 41/50
# 12/12 [==============================] - 5s 396ms/step - loss: 0.0329 - accuracy: 0.9919 - val_loss: 0.9623 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 42/50
# 12/12 [==============================] - 5s 403ms/step - loss: 0.0269 - accuracy: 0.9960 - val_loss: 0.9731 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 43/50
# 12/12 [==============================] - 5s 430ms/step - loss: 0.0238 - accuracy: 0.9960 - val_loss: 0.9752 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 44/50
# 12/12 [==============================] - 5s 402ms/step - loss: 0.0365 - accuracy: 0.9879 - val_loss: 0.9622 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 45/50
# 12/12 [==============================] - 5s 388ms/step - loss: 0.0259 - accuracy: 0.9960 - val_loss: 0.9643 - val_accuracy: 0.7500 - lr: 1.0000e-05
# Epoch 46/50
# 12/12 [==============================] - 5s 405ms/step - loss: 0.0209 - accuracy: 0.9973 - val_loss: 0.9664 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 47/50
# 12/12 [==============================] - 5s 392ms/step - loss: 0.0267 - accuracy: 0.9933 - val_loss: 0.9694 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 48/50
# 12/12 [==============================] - 5s 415ms/step - loss: 0.0235 - accuracy: 0.9933 - val_loss: 0.9708 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 49/50
# 12/12 [==============================] - 5s 380ms/step - loss: 0.0261 - accuracy: 0.9960 - val_loss: 0.9694 - val_accuracy: 0.7639 - lr: 1.0000e-05
# Epoch 50/50
# 12/12 [==============================] - 5s 434ms/step - loss: 0.0271 - accuracy: 0.9973 - val_loss: 0.9781 - val_accuracy: 0.7639 - lr: 1.0000e-05

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
               horizontalalignment="center",
               color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# Etape de prédiction
p_test = model.predict(X_test).argmax(axis=1)
# Matrice de confusion
cm = confusion_matrix(np.argmax(y_test, axis= 1), p_test)
plot_confusion_matrix(cm, list(range(5)))

misclassified_idx = np.where(p_test != np.argmax(y_test, axis= 1))[0]
i = np.random.choice(misclassified_idx)
plt.imshow(X_test[i], cmap='gray')
plt.title("True label: %s Predicted: %s" % (labels[np.argmax(y_test[i])], labels[p_test[i]]));
# Out:
# 6/6 [==============================] - 1s 54ms/step
# Confusion matrix, without normalization
# [[39  0  0  0]
#  [ 0 53  1 10]
#  [ 0  3 34  1]
#  [ 0  7  1 37]]

# %%
test =  tf.keras.preprocessing.image.load_img("test/adenocarcinoma/000109 (2).png", target_size = (128, 128))
display(test)
test =  tf.keras.preprocessing.image.img_to_array(test)
test = np.expand_dims(test, 0)
result = model.predict(test/255.0)
print(result)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
# 1/1 [==============================] - 0s 55ms/step
# [[3.8700474e-08 9.9982005e-01 2.7913109e-06 1.7707290e-04]]
